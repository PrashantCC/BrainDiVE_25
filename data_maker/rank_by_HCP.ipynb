# %%
import numpy as np
import nibabel as nib
def load_from_nii(nii_file):
    return nib.load(nii_file).get_fdata()

# cortex is an optional import
import cortex
# from cortex import config  #I commented because not used anywhere
#from cortex.options import config
#config.set('webgl_viewopts', "specularity", "0.0")
#config.set("curvature", "contrast", "0.1")
#config.set('webgl', 'colormaps', "/user_data/afluo/anaconda3/envs/pycortex2/share/pycortex/colormaps")

#import h5py
#import matplotlib.pyplot as plt

#import pickle
#import os
#from scipy.io import loadmat

# %%
all_subject_rois = dict()
# nsd_root = '/lab_data/tarrlab/common/datasets/NSD'
nsd_root = '/data6/shubham/PC/data/BrinDiVE_fromPrince/nsd_data'

# for subject in [1,2,3,4,5,6,7,8]:
for subject in [1,2,5,7]:
    print("Processing ", subject)
    roi_strings = "HCP_MMP1.nii.gz"
    raw_path = "{}/nsddata_betas/ppdata/subj0{}/func1pt8mm/betas_fithrf_GLMdenoise_RR/ncsnr.nii.gz".format(nsd_root, subject)
    raw_data = load_from_nii(raw_path)
    
    full_path = "{}/nsddata/ppdata/subj0{}/func1pt8mm/roi/{}".format(nsd_root, subject, roi_strings)
    all_roi = load_from_nii(full_path)
    all_rois_long = all_roi.astype(np.int64)
    unique_rois = np.unique(all_rois_long)
    unique_rois = unique_rois[unique_rois>0.5]

    roi_id = []
    roi_ncnsr = []

    for i in unique_rois:
        selected_mask = (all_rois_long==i)
        selected_ncnsr = raw_data[selected_mask]
        roi_id.append(i)
        roi_ncnsr.append(np.nanmean(selected_ncnsr))
    
    roi_id = np.array(roi_id)
    roi_ncnsr = np.array(roi_ncnsr)
    sorted_idx = np.argsort(roi_ncnsr)[::-1]   #give the indices that would sort the given array in discending order
    sorted_roi_id = roi_id[sorted_idx]
    all_subject_rois[subject] = np.copy(sorted_roi_id[:])
# Out:
# Processing  1
# Processing  2
# Processing  5
# Processing  7

# %%
# Not so good code, should re-write for clarity
roi_list = []
roi_ranks = []
for i in range(1,181):
    roi_list.append(i)
    roi_ranks.append([])
    # for subj in [1,2,3,4,5,6,7,8]:
    for subj in [1,2,5,7]:
        roi_ranks[-1].append(all_subject_rois[subj].tolist().index(i))

roi_list = np.array(roi_list)
roi_ranks = np.array(roi_ranks)
print(roi_ranks)
print(roi_ranks.shape)
roi_ranks_mean = np.mean(roi_ranks, axis=1)
print(roi_ranks_mean.shape)
best = np.argsort(roi_ranks_mean)

# Change the location depending on where you want to save this.
# np.save("/lab_data/tarrlab/afluo/NSD_zscored/best_HCP.npy",roi_list[best])
np.save("/data6/shubham/PC/data/results_preprocessed/best_HCP.npy",roi_list[best])
# Out:
# [[ 33  25  27  30]
#  [  3   2   4   0]
#  [ 88  88  65  62]
#  [ 30  30  25  26]
#  [ 21  22  26  38]
#  [  7   5  15  11]
#  [ 12   3  10   4]
#  [158 172 167 174]
#  [160 154 159 178]
#  [ 62  74  47  35]
#  [ 42  51  41  49]
#  [ 55  80  70  68]
#  [ 29  55  24  52]
#  [ 77  77  79  77]
#  [ 69  39  62  67]
#  [ 19  57  22  22]
#  [ 11  21  21  12]
#  [ 18  16  18  15]
#  [  9  19  11  16]
#  [ 15   8   3   7]
#  [ 24  26   2  20]
#  [ 23  32  17  18]
#  [  0   0  20   1]
#  [175 159 174 162]
#  [ 43  59  74  75]
#  [ 56 102 126 109]
#  [ 31  44  40  51]
#  [ 36  46  61  39]
#  [ 50  38  51  32]
#  [ 45  36  58  50]
#  [ 25  12  33  29]
#  [100  96  82  96]
#  [ 40  34  42  46]
#  [ 65  52  63  59]
#  [ 74  48  72  55]
#  [140 156 150 140]
#  [ 84 103  87  81]
#  [ 87  93  78  70]
#  [126 151 112 129]
#  [157 170 147 157]
#  [147 168 161 166]
#  [ 71 100  90  86]
#  [ 79  98 104 124]
#  [107 111 111  97]
#  [ 58  60  43  58]
#  [ 49  33  37  47]
#  [109  86  83  57]
#  [ 32  50  35  33]
#  [ 44  47  48  48]
#  [ 39  23  38  19]
#  [162 158 164 167]
#  [139 135 108  88]
#  [152 166 163 177]
#  [166 145 143  98]
#  [163 171 146 134]
#  [114 125 139 106]
#  [117 116 103 113]
#  [115 120  86 105]
#  [ 95 138 133 125]
#  [112 130 136 142]
#  [146 142 130 154]
#  [113 110 121 114]
#  [ 81  79  92  80]
#  [134 122 124 136]
#  [ 90  85  75 103]
#  [ 92  87  69  94]
#  [ 75  76  99  82]
#  [ 76  67  97  74]
#  [ 80  75  81 101]
#  [ 99  83  93 107]
#  [ 93  95 125 110]
#  [136 115 131 128]
#  [ 57  73  55  79]
#  [ 82  91 110 100]
#  [ 59  64 116  99]
#  [ 96  99 122 104]
#  [130 134 117 131]
#  [101  71  89  61]
#  [ 67  72  67  84]
#  [ 34  53  52  54]
#  [ 68  49  50  40]
#  [ 66  63  49  56]
#  [ 97  92  60  73]
#  [106 106  91  83]
#  [121 105  80 130]
#  [ 91 113 123 117]
#  [ 73 109 134 116]
#  [131 132 144 122]
#  [149 139 137 132]
#  [145 178 171 161]
#  [154 144 142 123]
#  [172 118 115 160]
#  [178 179 179 176]
#  [156  82 158 156]
#  [ 26  31  31  37]
#  [103  65  57  41]
#  [ 89  62  95  60]
#  [108  84  94  93]
#  [143 164 155 141]
#  [118 155 145 155]
#  [141 174 100 158]
#  [155 173 160 168]
#  [173 165 132 151]
#  [125 141 169 146]
#  [ 54 114 140 112]
#  [104 121 101 137]
#  [150 177 157 159]
#  [110 127 129 118]
#  [123 128 135 115]
#  [168 160 153 165]
#  [105 104 113 102]
#  [165 140 128 175]
#  [148 167 141 139]
#  [127 143 119 120]
#  [102 133 109 163]
#  [ 41  61  45  53]
#  [ 70  54  39  45]
#  [177 153 175 152]
#  [ 83  81  66  76]
#  [167 148 165 153]
#  [ 64  97  54  72]
#  [144  94 127  85]
#  [164 150 148 172]
#  [135 163 170 148]
#  [122 146 168 126]
#  [ 35  20  29  27]
#  [ 47  18  30  23]
#  [129 112 106 121]
#  [ 94 101  88  87]
#  [128 107 107 108]
#  [170 126 156 169]
#  [161 124 138 133]
#  [111  70  76  92]
#  [174 157 177 164]
#  [124 117 120  95]
#  [ 63  41  64  44]
#  [ 14  35  32  25]
#  [ 16  11  12   9]
#  [ 38  45  53  28]
#  [  4  10   6   3]
#  [  1   1  13   8]
#  [ 27  42  23  34]
#  [ 20  13  14  14]
#  [ 52  37  59  69]
#  [ 46  28  46  42]
#  [ 17  17   7  17]
#  [ 86  89  77  91]
#  [ 51  43  73  65]
#  [ 85  69  85  89]
#  [ 53  40  34  43]
#  [ 60  58  56  63]
#  [ 48  68  44  36]
#  [ 22  29  36  71]
#  [ 10   7   8  21]
#  [ 28  24  19  13]
#  [  6   6   0   2]
#  [  2  15   1   6]
#  [ 13   9   9   5]
#  [  5  14  16  10]
#  [  8   4   5  31]
#  [ 61  56  84  66]
#  [ 72  66  71  64]
#  [ 37  27  28  24]
#  [153 175 172 179]
#  [137 137 149 147]
#  [179 161 176 171]
#  [138 131 102 150]
#  [133 147 118 135]
#  [ 78  90  98  78]
#  [142 123 152 127]
#  [116 108  68  90]
#  [171 136 166 143]
#  [176 176 162 173]
#  [151 162 173 145]
#  [120 149 178 144]
#  [132  78 105 111]
#  [159 152 154 149]
#  [169 169 151 170]
#  [ 98 119  96 138]
#  [119 129 114 119]]
# (180, 4)
# (180,)
